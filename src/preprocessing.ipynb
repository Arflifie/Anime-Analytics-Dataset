# %%
import pandas as pd
data = pd.read_csv("../data/raw/anime_dataset.csv")
data = data[["title", "popularity", "favorites", "studios"]]
data.to_csv("../data/processed/anime_dataset_pre.csv", index=False)

# %%
print(data.head())
print(data.shape)
print(data.info())
print(data.describe())
# Out:
#                              title  popularity  favorites         studios
# 0                     Cowboy Bebop          41      89485         Sunrise
# 1  Cowboy Bebop: Tengoku no Tobira         658       1782           Bones
# 2                           Trigun         265      17610        Madhouse
# 3               Witch Hunter Robin        1989        707         Sunrise
# 4                   Bouken Ou Beet        5891         18  Toei Animation
# (30075, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30075 entries, 0 to 30074
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       30075 non-null  object
#  1   popularity  30075 non-null  int64
#  2   favorites   30075 non-null  int64
#  3   studios     18137 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 940.0+ KB
# None
#          popularity      favorites
# count  30075.000000   30075.000000
# mean   14957.319501     429.132801
# std     8634.251988    4550.008408
# min        1.000000       0.000000
# 25%     7483.000000       0.000000
# 50%    14946.000000       1.000000
# 75%    22428.000000      17.000000
# max    29935.000000  251194.000000

# %%
print(data.isnull().sum())
data = data.dropna()
# Out:
# title             0
# popularity        0
# favorites         0
# studios       11938
# dtype: int64

# %%
print(data.duplicated().sum())
data.drop_duplicates(inplace=True)
# Out:
# 89

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
data["studios"] = encoder.fit_transform(data["studios"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from sklearn.preprocessing import LabelEncoder
#       2 encoder = LabelEncoder()
#       3 data["studios"] = encoder.fit_transform(data["studios"])
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data[["popularity", "favorites"]] = scaler.fit_transform(data[["popularity", "favorites"]])

# %%
data_pre = pd.read_csv("../data/processed/anime_dataset_pre.csv")
data = pd.read_csv("../data/processed/anime_dataset_pre2.csv")
data_pre["studios_name"] = data["studios"]
data_pre.to_csv("../data/processed/anime_dataset_pre.csv", index=False)
print("Selesai! Kolom 'studios_name' berhasil ditambahkan.")
# Out:
# Selesai! Kolom 'studios_name' berhasil ditambahkan.
